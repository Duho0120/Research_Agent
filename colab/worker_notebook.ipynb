# %% [markdown]
# # Kaggle Research Agent Colab Worker
#
# Mount or sync this project folder, then run the worker to execute pending jobs.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Change this path to your synced project directory.
# %cd /content/drive/MyDrive/kaggle_research_agent_project

# %%
# !python colab/worker.py
